# %%
from langgraph.types import TimeoutPolicy, RetryPolicy
from mypy import defaults

builder.add_node(
    "call_model",
    call_model,
    timeout=TimeoutPolicy(
        run_timeout=60
    )
)

builder.add_node(
    "call_node",
    call_node,
    retry_policy=RetryPolicy(max_retries=3)
    error_handler=error_handler # or route to other node by Command function.
)

set_node_defaults 为所有节点设置默认配置，即是Graph defaults
